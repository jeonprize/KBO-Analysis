# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
import pandas as pd 
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
plt.rc("font",family="Malgun Gothic")
plt.rc("axes",unicode_minus=False)
plt.style.use("fivethirtyeight")

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

# %%
pd.set_option("display.max_columns",32)

# %%
df = pd.read_csv("SL_batter_data.csv")
df
# Out:
#       팀  시즌   이름 포지션   WAR   출장   타석   타수   득점   안타  2루타  3루타  홈런   루타   타점  \
# 0    삼성  16  최형우  LF  7.75  138  618  519   99  195   46    2  31  338  144
# 1    삼성  15  나바로  2B  6.45  140  643  534  126  153   19    1  48  318  137
# 2    삼성  15  박석민  3B  5.38  135  559  448   90  144   25    0  26  247  116
# 3    삼성  18   러프  1B  5.28  137  597  506   97  167   32    4  33  306  125
# 4    삼성  15  구자욱  1B  4.99  116  465  410   97  143   33    5  11  219   57
# ..   ..  ..  ...  ..   ...  ...  ...  ...  ...  ...  ...  ...  ..  ...  ...
# 162  삼성  18  손주인  2B -0.70   98  297  265   26   63   10    0   4   85   28
# 163  삼성  19  김동엽  DH -0.84   60  211  195   15   42    4    1   6   66   25
# 164  삼성  20  박계범  SS -0.92   80  175  164   21   32    7    0   3   48   16
# 165  삼성  20  이성규  1B -0.92   98  245  216   25   39    7    1  10   78   30
# 166  삼성  16  김재현  SS -0.97  122  215  188   25   41    7    0   0   48   14
#
#      도루  볼넷  사구  고4   삼진  병살      타율      출루      장타      OPS
# 0     2  83   9   8   83  12   .376    .464    .651    1.116
# 1    22  93   6   8   72  10   .287    .393    .596     .988
# 2     3  83  19   0   97  13   .321    .441    .551     .992
# 3     5  65  18   0  107  17   .330    .419    .605    1.024
# 4    17  45   6   0   79   3   .349    .417    .534     .951
# ..   ..  ..  ..  ..  ...  ..     ...     ...     ...      ...
# 162   3  11   7   0   40  11   .238    .282    .321     .603
# 163   2  12   2   0   47   2   .215    .265    .338     .604
# 164   3   7   0   0   42   3   .195    .227    .293     .519
# 165   3  18   5   0   64   7   .181    .257    .361     .618
# 166   1   8   7   0   42  10   .218    .275    .255     .530
#
# [167 rows x 25 columns]

# %%
df = df[df["시즌"]== 20]
df
# Out:
#       팀  시즌    이름 포지션   WAR   출장   타석   타수  득점   안타  2루타  3루타  홈런   루타  타점  \
# 12   삼성  20   구자욱  LF  3.35  118  510  446  70  137   27    2  15  213  78
# 14   삼성  20   김상수  2B  3.25  120  471  404  71  123   18    3   5  162  47
# 17   삼성  20   강민호   C  3.00  119  393  355  46  102   14    0  19  173  61
# 21   삼성  20   박해민  CF  2.48  132  541  489  84  142   18    5  11  203  55
# 23   삼성  20   김동엽  DH  2.21  115  451  413  60  129   21    0  20  210  74
# 39   삼성  20  살라디노  LF  1.35   44  163  132  26   37    8    0   6   63  27
# 41   삼성  20   이원석  3B  1.27  121  467  403  46  108   17    0  13  164  74
# 44   삼성  20   김호재  3B  1.11   65  138  118  19   38    5    0   1   46  10
# 55   삼성  20   강한울  SS  0.55   34  122  105  13   32    3    0   1   38  10
# 58   삼성  20   최영진  3B  0.50   58  118  101  15   30    3    0   1   36  11
# 63   삼성  20   이학주  SS  0.35   64  243  206  30   47   11    0   4   70  28
# 65   삼성  20   이성곤  1B  0.27   62  154  139  16   39    7    0   5   61  18
# 75   삼성  20   김지찬  2B  0.12  135  287  254  47   59    5    1   1   69  13
# 76   삼성  20   송준석  RF  0.12   32   50   47   5   13    5    0   1   21   7
# 80   삼성  20   김성윤  LF  0.08    9    9    7   1    2    1    0   0    3   0
# 88   삼성  20   권정웅   C  0.02    3    2    1   0    0    0    0   0    0   0
# 99   삼성  20   김재현  SS -0.05   35   18   14   4    2    0    0   0    2   4
# 109  삼성  20   김도환   C -0.08   34   49   41   2    9    2    0   0   11   9
# 114  삼성  20   김성표  CF -0.10   15    8    8   1    1    0    0   0    1   0
# 120  삼성  20   김민수   C -0.12   17   26   23   3    4    0    0   0    4   1
# 122  삼성  20   백승민  1B -0.13    7   12    9   0    0    0    0   0    0   1
# 130  삼성  20   박찬도  LF -0.15   51  116   96  20   21    5    0   1   29   8
# 140  삼성  20   김응민   C -0.23   45   85   76   7   17    1    0   0   18   5
# 149  삼성  20   양우현  2B -0.30    7   24   23   0    3    0    0   0    3   0
# 152  삼성  20   김헌곤  RF -0.31   97  283  254  26   63    8    0   3   80  34
# 155  삼성  20   박승규  RF -0.35   91  196  182  24   47   11    0   1   61  14
# 161  삼성  20    팔카  DH -0.67   51  217  196  17   41    7    0   8   72  23
# 164  삼성  20   박계범  SS -0.92   80  175  164  21   32    7    0   3   48  16
# 165  삼성  20   이성규  1B -0.92   98  245  216  25   39    7    1  10   78  30
#
#      도루  볼넷  사구  고4  삼진  병살      타율      출루      장타     OPS
# 12   19  51   8   3  91   4   .307    .385    .478    .863
# 14   10  55   8   1  55  16   .304    .397    .401    .798
# 17    0  31   4   2  54  17   .287    .349    .487    .836
# 21   34  39   3   1  77   7   .290    .345    .415    .760
# 23    4  29   4   0  79  14   .312    .360    .508    .869
# 39    6  23   7   0  41   3   .280    .411    .477    .888
# 41    0  49   2   1  82   7   .268    .341    .407    .748
# 44    2  16   3   0  19   1   .322    .416    .390    .806
# 55    1  11   0   0  24   3   .305    .368    .362    .729
# 58    2  13   2   0  16   3   .297    .385    .356    .741
# 63    6  26   2   1  58   3   .228    .314    .340    .654
# 65    2  11   0   0  38   3   .281    .329    .439    .768
# 75   21  24   2   0  44   1   .232    .301    .272    .573
# 76    0   2   1   0   6   4   .277    .320    .447    .767
# 80    0   1   1   0   1   0   .286    .444    .429    .873
# 88    0   1   0   0   0   0   .000    .500    .000    .500
# 99    0   3   0   0   3   1   .143    .294    .143    .437
# 109   0   5   0   0  16   0   .220    .292    .268    .560
# 114   1   0   0   0   2   0   .125    .125    .125    .250
# 120   0   2   0   0   6   0   .174    .240    .174    .414
# 122   0   1   2   0   2   0   .000    .250    .000    .250
# 130   5  15   1   1  22   2   .219    .325    .302    .627
# 140   0   5   1   0  22   1   .224    .281    .237    .517
# 149   0   1   0   0   5   1   .130    .167    .130    .297
# 152   7  22   3   0  31   7   .248    .312    .315    .627
# 155   4   7   3   0  32   4   .258    .297    .335    .632
# 161   2  18   0   0  58   5   .209    .272    .367    .639
# 164   3   7   0   0  42   3   .195    .227    .293    .519
# 165   3  18   5   0  64   7   .181    .257    .361    .618

# %%
df["팀"].unique()
# Out:
# array(['삼성'], dtype=object)

# %%
df["포지션"].unique()
# Out:
# array(['LF', '2B', 'C', 'CF', 'DH', '3B', 'SS', '1B', 'RF'], dtype=object)

# %%
print(f"인원 : {df.shape[0]}")
print(f"포지션 : {df['포지션'].unique()}")
# Out:
# 인원 : 29
# 포지션 : ['LF' '2B' 'C' 'CF' 'DH' '3B' 'SS' '1B' 'RF']

# %%
sns.countplot(df["포지션"])
# Out:
# <AxesSubplot:xlabel='포지션', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 12 to 165
# Data columns (total 25 columns):
# 팀      29 non-null object
# 시즌     29 non-null int64
# 이름     29 non-null object
# 포지션    29 non-null object
# WAR    29 non-null float64
# 출장     29 non-null int64
# 타석     29 non-null int64
# 타수     29 non-null int64
# 득점     29 non-null int64
# 안타     29 non-null int64
# 2루타    29 non-null int64
# 3루타    29 non-null int64
# 홈런     29 non-null int64
# 루타     29 non-null int64
# 타점     29 non-null int64
# 도루     29 non-null int64
# 볼넷     29 non-null int64
# 사구     29 non-null int64
# 고4     29 non-null int64
# 삼진     29 non-null int64
# 병살     29 non-null int64
# 타율     29 non-null object
# 출루     29 non-null object
# 장타     29 non-null object
# OPS    29 non-null object
# dtypes: float64(1), int64(17), object(7)
# memory usage: 7.1+ KB

# %% [markdown]
# ### 삼성라이온즈는 어떤 포지션을 보강해야할까?

# %%
df.groupby(["포지션"])["WAR"].sum()
# Out:
# 포지션
# 1B   -0.78
# 2B    3.07
# 3B    2.88
# C     2.59
# CF    2.38
# DH    1.54
# LF    4.63
# RF   -0.54
# SS   -0.07
# Name: WAR, dtype: float64

# %% [markdown]
# #### - 다른 팀 선수와 비교하기 위해 1위와 2위를 했던 NC와 두산의 선수가 담긴 데이터를 만든다.
